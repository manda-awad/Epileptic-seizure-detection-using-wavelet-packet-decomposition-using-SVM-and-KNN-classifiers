# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pywt

# %%
from IPython.display import Image
Image("img/project_schematic.jpg")

# %%
from IPython.display import Image
Image("img/tree.jpg")

# %% [markdown]
# # Impoting EEG signals files (F files, N files and S files)

# %%
#This Program is done by Manda Ahmad Awad

F_feature = np.zeros((100,80))
files_F = []
for i in range(0,100):
    if i < 10:
        filename_F = 'F00'+str(i)+'.txt'
        files_F.append(filename_F)
    elif i < 100:
        filename_F = 'F0'+str(i)+'.txt'
        files_F.append(filename_F)
   
    F_data = np.loadtxt(filename_F)
    F_feature[i,:]= (features_extraction(data_file=F_data,wavelet_mother='db4', num_levels=4))
         
df_features_F = pd.DataFrame(F_feature,index= files_F, columns=['entropy(4,0)','entropy(4,1)','entropy(4,2)','entropy(4,3)','entropy(4,4)',
                                     'entropy(4,5)','entropy(4,6)','entropy(4,7)','entropy(4,8)','entropy(4,9)',
                                     'entropy(4,10)','entropy(4,11)','entropy(4,12)','entropy(4,13)','entropy(4,14)',
                                     'entropy(4,15)','std(4,0)','std(4,1)','std(4,2)','std(4,3)','std(4,4)',
                                     'std(4,5)','std(4,6)','std(4,7)','std(4,8)','std(4,9)',
                                     'std(4,10)','std(4,11)','std(4,12)','std(4,13)','std(4,14)',
                                     'std(4,15)','mean(4,0)','mean(4,1)','mean(4,2)','mean(4,3)','mean(4,4)',
                                     'mean(4,5)','mean(4,6)','mean(4,7)','mean(4,8)','mean(4,9)',
                                     'mean(4,10)','mean(4,11)','mean(4,12)','mean(4,13)','mean(4,14)',
                                     'mean(4,15)','max(4,0)','max(4,1)','max(4,2)','max(4,3)','max(4,4)',
                                     'max(4,5)','max(4,6)','max(4,7)','max(4,8)','max(4,9)',
                                     'max(4,10)','max(4,11)','max(4,12)','max(4,13)','max(4,14)',
                                     'max(4,15)','min(4,0)','min(4,1)','min(4,2)','min(4,3)','min(4,4)',
                                     'min(4,5)','min(4,6)','min(4,7)','min(4,8)','min(4,9)',
                                     'min(4,10)','min(4,11)','min(4,12)','min(4,13)','min(4,14)',
                                     'min(4,15)'])
df_features_F['target']=np.zeros((100,1), dtype=int)
df_features_F.head(10)
# Out:
#           entropy(4,0)  entropy(4,1)  entropy(4,2)  entropy(4,3)  \
# F000.txt   2492.612550   1681.081901    973.747561   1316.377990
# F001.txt   2355.939459   1487.622241    985.731051   1318.009093
# F002.txt   2783.642492   1918.857563   1182.335600   1514.226654
# F003.txt   2639.265123   2019.913331   1379.245031   1812.794677
# F004.txt   2500.087010   1734.293896   1055.549153   1372.068952
# F005.txt   2645.405615   2215.261740   1629.325006   1938.601278
# F006.txt   2433.470841   1677.581458    840.285953   1187.094984
# F007.txt   2380.828277   1853.498483   1301.051444   1630.436629
# F008.txt   2554.193882   1862.197878   1180.318514   1425.859435
# F009.txt   3451.993845   2155.308356   1533.267180   1750.626315
#
#           entropy(4,4)  entropy(4,5)  entropy(4,6)  entropy(4,7)  \
# F000.txt    171.889978    394.418511    778.658649    640.153302
# F001.txt    107.821443    470.788565    916.824202    722.271413
# ...

# %%
#This Program is done by Manda Ahmad Awad
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pywt 
N_feature = np.zeros((100,80))
files_N = []
for i in range(0,100):
    if i < 10:
        filename_N = 'N00'+str(i)+'.txt'
        files_N.append(filename_N)
    elif i < 100:
        filename_N = 'N0'+str(i)+'.txt'
        files_N.append(filename_N)
   
    N_data = np.loadtxt(filename_N)
    N_feature[i,:]= (features_extraction(data_file=N_data,wavelet_mother='db4', num_levels=4))
         
df_features_N = pd.DataFrame(N_feature,index= files_N, columns=['entropy(4,0)','entropy(4,1)','entropy(4,2)','entropy(4,3)','entropy(4,4)',
                                     'entropy(4,5)','entropy(4,6)','entropy(4,7)','entropy(4,8)','entropy(4,9)',
                                     'entropy(4,10)','entropy(4,11)','entropy(4,12)','entropy(4,13)','entropy(4,14)',
                                     'entropy(4,15)','std(4,0)','std(4,1)','std(4,2)','std(4,3)','std(4,4)',
                                     'std(4,5)','std(4,6)','std(4,7)','std(4,8)','std(4,9)',
                                     'std(4,10)','std(4,11)','std(4,12)','std(4,13)','std(4,14)',
                                     'std(4,15)','mean(4,0)','mean(4,1)','mean(4,2)','mean(4,3)','mean(4,4)',
                                     'mean(4,5)','mean(4,6)','mean(4,7)','mean(4,8)','mean(4,9)',
                                     'mean(4,10)','mean(4,11)','mean(4,12)','mean(4,13)','mean(4,14)',
                                     'mean(4,15)','max(4,0)','max(4,1)','max(4,2)','max(4,3)','max(4,4)',
                                     'max(4,5)','max(4,6)','max(4,7)','max(4,8)','max(4,9)',
                                     'max(4,10)','max(4,11)','max(4,12)','max(4,13)','max(4,14)',
                                     'max(4,15)','min(4,0)','min(4,1)','min(4,2)','min(4,3)','min(4,4)',
                                     'min(4,5)','min(4,6)','min(4,7)','min(4,8)','min(4,9)',
                                     'min(4,10)','min(4,11)','min(4,12)','min(4,13)','min(4,14)',
                                     'min(4,15)'])

df_features_N['target'] = np.zeros((100,1), dtype=int)
df_features_N.head(10)
# Out:
#           entropy(4,0)  entropy(4,1)  entropy(4,2)  entropy(4,3)  \
# N000.txt   2439.083263   1730.155463   1121.045649   1441.187215
# N001.txt   2387.534482   1906.176274   1075.591789   1477.119426
# N002.txt   2518.403550   1878.529464   1274.890405   1533.704626
# N003.txt   2315.042369   1921.653155   1222.437918   1547.535810
# N004.txt   2422.600661   1915.589206   1220.868564   1583.325179
# N005.txt   2758.141328   2438.728530   2094.392756   2274.091607
# N006.txt   2425.947353   1928.088942   1200.307558   1584.754900
# N007.txt   2398.791780   1775.524759   1111.299812   1390.573071
# N008.txt   2521.667857   1670.805419   1115.672040   1374.842988
# N009.txt   2555.081024   1984.820301   1422.231265   1712.504354
#
#           entropy(4,4)  entropy(4,5)  entropy(4,6)  entropy(4,7)  \
# N000.txt    293.430578    646.492800    975.876593    808.788726
# N001.txt     63.437759    453.102914    925.981897    730.480671
# ...

# %%
#This Program is done by Manda Ahmad Awad
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pywt 
S_feature = np.zeros((100,80))
files_S = []
for i in range(0,100):
    if i < 10:
        filename_S = 'S00'+str(i)+'.txt'
        files_S.append(filename_S)
    elif i < 100:
        filename_S = 'S0'+str(i)+'.txt'
        files_S.append(filename_S)
   
    S_data = np.loadtxt(filename_S)
    S_feature[i,:]= (features_extraction(data_file=S_data,wavelet_mother='db4', num_levels=4))
         
df_features_S = pd.DataFrame(S_feature,index= files_S, columns=['entropy(4,0)','entropy(4,1)','entropy(4,2)','entropy(4,3)','entropy(4,4)',
                                     'entropy(4,5)','entropy(4,6)','entropy(4,7)','entropy(4,8)','entropy(4,9)',
                                     'entropy(4,10)','entropy(4,11)','entropy(4,12)','entropy(4,13)','entropy(4,14)',
                                     'entropy(4,15)','std(4,0)','std(4,1)','std(4,2)','std(4,3)','std(4,4)',
                                     'std(4,5)','std(4,6)','std(4,7)','std(4,8)','std(4,9)',
                                     'std(4,10)','std(4,11)','std(4,12)','std(4,13)','std(4,14)',
                                     'std(4,15)','mean(4,0)','mean(4,1)','mean(4,2)','mean(4,3)','mean(4,4)',
                                     'mean(4,5)','mean(4,6)','mean(4,7)','mean(4,8)','mean(4,9)',
                                     'mean(4,10)','mean(4,11)','mean(4,12)','mean(4,13)','mean(4,14)',
                                     'mean(4,15)','max(4,0)','max(4,1)','max(4,2)','max(4,3)','max(4,4)',
                                     'max(4,5)','max(4,6)','max(4,7)','max(4,8)','max(4,9)',
                                     'max(4,10)','max(4,11)','max(4,12)','max(4,13)','max(4,14)',
                                     'max(4,15)','min(4,0)','min(4,1)','min(4,2)','min(4,3)','min(4,4)',
                                     'min(4,5)','min(4,6)','min(4,7)','min(4,8)','min(4,9)',
                                     'min(4,10)','min(4,11)','min(4,12)','min(4,13)','min(4,14)',
                                     'min(4,15)'])
df_features_S['target'] = np.ones((100,1), dtype=int)
df_features_S.head(10)
# Out:
#           entropy(4,0)  entropy(4,1)  entropy(4,2)  entropy(4,3)  \
# S000.txt   3084.365360   3086.301893   2420.859983   2818.362704
# S001.txt   3476.423592   3183.126602   2806.167108   3135.740704
# S002.txt   3482.405149   3137.614061   3042.656475   3201.363249
# S003.txt   3237.160949   2959.995603   2932.371689   3133.661743
# S004.txt   2756.161903   2896.349927   2209.131968   2491.710557
# S005.txt   3325.304667   3126.054096   2426.111077   2787.360182
# S006.txt   2689.478613   2670.675768   2023.467464   2337.136312
# S007.txt   3156.775174   2283.592811   2006.750500   2146.181123
# S008.txt   3251.089944   3458.610859   2419.870459   3021.435465
# S009.txt   3289.517313   3247.951387   2473.391913   2858.765247
#
#           entropy(4,4)  entropy(4,5)  entropy(4,6)  entropy(4,7)  \
# S000.txt   1110.698632   1643.173350   2201.502632   1938.067454
# S001.txt   1506.246242   1981.200259   2503.634054   2469.912487
# ...

# %% [markdown]
# # Feature extraction function using wavelet decomposition packet and daubichies 4 type

# %%
def features_extraction(data_file,wavelet_mother, num_levels):
        
    EEG_entropies = []
    EEG_std = []
    EEG_mean = []
    EEG_max = []
    EEG_min = []
#    EEG_features = []
    wavelet_mother = 'db4'
    num_levels = 4
        

    wp = pywt.WaveletPacket(data=data_file, wavelet=wavelet_mother, mode='symmetric',maxlevel=num_levels)

    #print(wp.data)
    #print(wp['a'].data) #1st level
    #print(wp['aa'].data) #second level
    #print(wp['aaa'].data) #third level
        #print(wp['aaaa'].data)
    #print('************************************************************************************')
    #print('444444444',wp['aaaa'].data)
    final_levels = [node.path for node in wp.get_level(4, 'natural')] #fourth level
    for i in final_levels:
        log_energy = np.sum(np.log(np.power(wp[i].data, 2)))
        EEG_entropies.append(log_energy)
        EEG_std.append(np.std(wp[i].data))
        EEG_mean.append(np.mean(wp[i].data))
        EEG_max.append(np.max(wp[i].data))
        EEG_min.append(np.min(wp[i].data))
        #EEG_features.append(log_energy)
        #EEG_features.append(np.std(wp[i].data))
        #EEG_features.append(np.mean(wp[i].data))
        #EEG_features.append(np.max(wp[i].data))
        #EEG_features.append(np.min(wp[i].data))
        
    #print(EEG_entropies, EEG_std, EEG_mean, EEG_max, EEG_min)
        
    #print(EEG_entropies,EEG_std,EEG_mean,EEG_max,EEG_min)
    #A = np.array([EEG_entropies,EEG_std,EEG_mean,EEG_max,EEG_min]).flatten()
#     A = np.array([EEG_features]).flatten()
#     print(A, A.shape)
#     df_features = pd.DataFrame(A,columns=['entropy(4,0)','entropy(4,1)','entropy(4,2)','entropy(4,3)','entropy(4,4)',
#                                          'entropy(4,5)','entropy(4,6)','entropy(4,7)','entropy(4,8)','entropy(4,9)',
#                                          'entropy(4,10)','entropy(4,11)','entropy(4,12)','entropy(4,13)','entropy(4,14)',
#                                          'entropy(4,15)','std(4,0)','std(4,1)','std(4,2)','std(4,3)','std(4,4)',
#                                          'std(4,5)','std(4,6)','std(4,7)','std(4,8)','std(4,9)',
#                                          'std(4,10)','std(4,11)','std(4,12)','std(4,13)','std(4,14)',
#                                          'std(4,15)','mean(4,0)','mean(4,1)','mean(4,2)','mean(4,3)','mean(4,4)',
#                                          'mean(4,5)','mean(4,6)','mean(4,7)','mean(4,8)','mean(4,9)',
#                                          'mean(4,10)','mean(4,11)','mean(4,12)','mean(4,13)','mean(4,14)',
#                                          'mean(4,15)','max(4,0)','max(4,1)','max(4,2)','max(4,3)','max(4,4)',
#                                          'max(4,5)','max(4,6)','max(4,7)','max(4,8)','max(4,9)',
#                                          'max(4,10)','max(4,11)','max(4,12)','max(4,13)','max(4,14)',
#                                          'max(4,15)','min(4,0)','min(4,1)','min(4,2)','min(4,3)','min(4,4)',
#                                          'min(4,5)','min(4,6)','min(4,7)','min(4,8)','min(4,9)',
#                                          'min(4,10)','min(4,11)','min(4,12)','min(4,13)','min(4,14)',
#                                          'min(4,15)'])
#     df_features.head(10)
    return np.array([EEG_entropies, EEG_std, EEG_mean, EEG_max, EEG_min]).flatten().reshape(1,80)
   
  
    
        

#OUT #['aaaa', 'aaad', 'aada', 'aadd', 'adaa', 'adad', 'adda', 'addd', 'daaa', 'daad', 'dada', 'dadd', 'ddaa', 'ddad', 'ddda', 'dddd']
#print(wp['dddd'].data)

# %%
df = pd.concat([df_features_F,df_features_N,df_features_S])

# %%
df
# Out:
#           entropy(4,0)  entropy(4,1)  entropy(4,2)  entropy(4,3)  \
# F000.txt   2492.612550   1681.081901    973.747561   1316.377990
# F001.txt   2355.939459   1487.622241    985.731051   1318.009093
# F002.txt   2783.642492   1918.857563   1182.335600   1514.226654
# F003.txt   2639.265123   2019.913331   1379.245031   1812.794677
# F004.txt   2500.087010   1734.293896   1055.549153   1372.068952
# ...                ...           ...           ...           ...
# S095.txt   2879.319536   3059.776040   2300.801367   2956.465692
# S096.txt   2724.429469   2595.860624   1900.947083   2231.628396
# S097.txt   3401.436895   3668.062206   2678.592760   3197.259692
# S098.txt   3084.840745   3234.313381   2331.192615   3040.992182
# S099.txt   3179.418024   3264.221424   2821.460574   3107.175801
#
#           entropy(4,4)  entropy(4,5)  entropy(4,6)  entropy(4,7)  \
# F000.txt    171.889978    394.418511    778.658649    640.153302
# ...

# %%
from sklearn.model_selection import train_test_split
X = df.drop('target', axis=1)
y = df['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Using SVM without Normalizing the data

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\manda\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[70  0]
#  [29  0]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        70
#            1       0.00      0.00      0.00        29
#
#     accuracy                           0.71        99
#    macro avg       0.35      0.50      0.41        99
# weighted avg       0.50      0.71      0.59        99
# C:\Users\manda\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
param_grid = {
    'C':[0.1,1,10,100,100],
    'gamma':[1,0.1,0.01,0.001,0.0001],
    'kernel':['rbf']
    
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# C:\Users\manda\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.647, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.642, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.652, total=   0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
grid_predictions = grid.predict(X_test)

# %%
print(confusion_matrix(y_test,grid_predictions))
# Out:
# [[70  0]
#  [29  0]]

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        70
#            1       0.00      0.00      0.00        29
#
#     accuracy                           0.71        99
#    macro avg       0.35      0.50      0.41        99
# weighted avg       0.50      0.71      0.59        99
# C:\Users\manda\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
df
# Out:
#           entropy(4,0)  entropy(4,1)  entropy(4,2)  entropy(4,3)  \
# F000.txt   2492.612550   1681.081901    973.747561   1316.377990
# F001.txt   2355.939459   1487.622241    985.731051   1318.009093
# F002.txt   2783.642492   1918.857563   1182.335600   1514.226654
# F003.txt   2639.265123   2019.913331   1379.245031   1812.794677
# F004.txt   2500.087010   1734.293896   1055.549153   1372.068952
# ...                ...           ...           ...           ...
# S095.txt   2879.319536   3059.776040   2300.801367   2956.465692
# S096.txt   2724.429469   2595.860624   1900.947083   2231.628396
# S097.txt   3401.436895   3668.062206   2678.592760   3197.259692
# S098.txt   3084.840745   3234.313381   2331.192615   3040.992182
# S099.txt   3179.418024   3264.221424   2821.460574   3107.175801
#
#           entropy(4,4)  entropy(4,5)  entropy(4,6)  entropy(4,7)  \
# F000.txt    171.889978    394.418511    778.658649    640.153302
# ...

# %% [markdown]
# # Normalizing Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df.drop('target', axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(df.drop('target', axis=1))

# %%
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])

# %%
df_feat.head()
# Out:
#    entropy(4,0)  entropy(4,1)  entropy(4,2)  entropy(4,3)  entropy(4,4)  \
# 0     -0.437769     -0.965787     -0.981428     -0.973395     -0.749812
# 1     -0.766363     -1.297879     -0.962866     -0.970851     -0.877304
# 2      0.261935     -0.557623     -0.658324     -0.664799     -0.918411
# 3     -0.085182     -0.384152     -0.353311     -0.199105     -0.565705
# 4     -0.419799     -0.874444     -0.854717     -0.886530     -0.767148
#
#    entropy(4,5)  entropy(4,6)  entropy(4,7)  entropy(4,8)  entropy(4,9)  ...  \
# 0     -1.003194     -1.039136     -0.961008     -0.531880     -0.833547  ...
# 1     -0.868943     -0.813019     -0.830911     -0.553768     -0.459642  ...
# 2     -0.726817     -0.652504     -0.739497     -0.954997     -1.083298  ...
# 3     -0.374108     -0.538841     -0.405186     -0.530225     -0.772557  ...
# 4     -0.968387     -0.997396     -0.969992     -0.533667     -0.754099  ...
#
# ...

# %%
X = scaled_features
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Using SVM classifier after normalizing the data

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\manda\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
predSVM = model.predict(X_test)

# %%
print(confusion_matrix(y_test,predSVM))
# Out:
# [[67  3]
#  [ 1 28]]

# %%
print(classification_report(y_test,predSVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        70
#            1       0.90      0.97      0.93        29
#
#     accuracy                           0.96        99
#    macro avg       0.94      0.96      0.95        99
# weighted avg       0.96      0.96      0.96        99

# %% [markdown]
# # Using KNN Classifier after normalizing the data

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=12) #the default number of neighbors = 5

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=12, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(X_test)

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[67  3]
#  [ 1 28]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        70
#            1       0.90      0.97      0.93        29
#
#     accuracy                           0.96        99
#    macro avg       0.94      0.96      0.95        99
# weighted avg       0.96      0.96      0.96        99

# %% [markdown]
# # Choosing K value

# %%
errors_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    errors_rate.append(np.mean(pred_i != y_test))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(range(1,40),errors_rate, linestyle='dashed', marker='o', markerfacecolor='yellow')
plt.title('Error Rate vs. K values')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')
